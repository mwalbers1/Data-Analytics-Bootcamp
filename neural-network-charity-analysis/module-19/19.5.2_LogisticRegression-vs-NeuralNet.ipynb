# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('datasets/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %% [markdown]
# ## Preprocess numerical data for neural network

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Logistic Regression model

# %%
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %% [markdown]
# ## Basic Neural network

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7361 - accuracy: 0.5503
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6823 - accuracy: 0.5885
# Epoch 3/50
# 18/18 [==============================] - 0s 979us/step - loss: 0.6384 - accuracy: 0.6441
# Epoch 4/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6058 - accuracy: 0.6840
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7049
# Epoch 6/50
# 18/18 [==============================] - 0s 939us/step - loss: 0.5598 - accuracy: 0.7274
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5439 - accuracy: 0.7465
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5304 - accuracy: 0.7517
# Epoch 9/50
# 18/18 [==============================] - 0s 883us/step - loss: 0.5191 - accuracy: 0.7604
# Epoch 10/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5102 - accuracy: 0.7691
# Epoch 11/50
# 18/18 [==============================] - 0s 823us/step - loss: 0.5025 - accuracy: 0.7726
# Epoch 12/50
# 18/18 [==============================] - 0s 814us/step - loss: 0.4964 - accuracy: 0.7622
# Epoch 13/50
# 18/18 [==============================] - 0s 940us/step - loss: 0.4904 - accuracy: 0.7760
# Epoch 14/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4855 - accuracy: 0.7760
# Epoch 15/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4815 - accuracy: 0.7743
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4774 - accuracy: 0.7795
# Epoch 17/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4742 - accuracy: 0.7812
# Epoch 18/50
# 18/18 [==============================] - 0s 882us/step - loss: 0.4710 - accuracy: 0.7795
# Epoch 19/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4681 - accuracy: 0.7865
# Epoch 20/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4654 - accuracy: 0.7847
# Epoch 21/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4627 - accuracy: 0.7882
# Epoch 22/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4605 - accuracy: 0.7882
# Epoch 23/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4587 - accuracy: 0.7917
# Epoch 24/50
# 18/18 [==============================] - 0s 882us/step - loss: 0.4568 - accuracy: 0.7951
# Epoch 25/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4554 - accuracy: 0.7934
# Epoch 26/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4537 - accuracy: 0.7917
# Epoch 27/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4521 - accuracy: 0.7917
# Epoch 28/50
# 18/18 [==============================] - 0s 942us/step - loss: 0.4507 - accuracy: 0.7951
# Epoch 29/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.7934
# Epoch 30/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4484 - accuracy: 0.7969
# Epoch 31/50
# 18/18 [==============================] - 0s 998us/step - loss: 0.4469 - accuracy: 0.7986
# Epoch 32/50
# 18/18 [==============================] - 0s 942us/step - loss: 0.4458 - accuracy: 0.8003
# Epoch 33/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4450 - accuracy: 0.8021
# Epoch 34/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4438 - accuracy: 0.8038
# Epoch 35/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4429 - accuracy: 0.7986
# Epoch 36/50
# 18/18 [==============================] - 0s 882us/step - loss: 0.4423 - accuracy: 0.7969
# Epoch 37/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4414 - accuracy: 0.7969
# Epoch 38/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4405 - accuracy: 0.7986
# Epoch 39/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4400 - accuracy: 0.7986
# Epoch 40/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.4392 - accuracy: 0.7986
# Epoch 41/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4383 - accuracy: 0.7986
# Epoch 42/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4377 - accuracy: 0.7986
# Epoch 43/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4371 - accuracy: 0.7986
# Epoch 44/50
# 18/18 [==============================] - 0s 1000us/step - loss: 0.4364 - accuracy: 0.7986
# Epoch 45/50
# 18/18 [==============================] - 0s 940us/step - loss: 0.4357 - accuracy: 0.7986
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4352 - accuracy: 0.7986
# Epoch 47/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4347 - accuracy: 0.7969
# Epoch 48/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4340 - accuracy: 0.7969
# Epoch 49/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4337 - accuracy: 0.7969
# Epoch 50/50
# 18/18 [==============================] - 0s 943us/step - loss: 0.4333 - accuracy: 0.7986
# 6/6 - 0s - loss: 0.4862 - accuracy: 0.7292 - 100ms/epoch - 17ms/step
# Loss: 0.48615530133247375, Accuracy: 0.7291666865348816
